# %% [markdown]
# Este código gera o gráfico da FIG 3

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np
import os
import glob

# Função para calcular média de uma lista
def calcular_media(lista):
    return sum(lista) / len(lista)

tamanho_fonte = 30

label_size = 20

x_label = 'Rodada de Treinamento'
y_label_acuracia = 'Acurácia'
y_label_loss = 'Perda'

x_fig = 11.0 #6.8
y_fig = 7.5 #5.5

formato = ".pdf"

line_width = 5

# Ler os dados do arquivo CSV
arquivos = [
    'TESTES/DATA_REGULAR/dnn/mnist/normal_iid_mnist_dnn_20%.csv',
    'TESTES/DATA_REGULAR/dnn/mnist/normal_iid_mnist_dnn_40%.csv',
    'TESTES/DATA_REGULAR/dnn/mnist/normal_iid_mnist_dnn_60%.csv',
    'TESTES/DATA_REGULAR/dnn/mnist/normal_iid_mnist_dnn_80%.csv',
    'TESTES/DATA_REGULAR/dnn/mnist/random_iid_mnist_dnn_20%.csv',
    'TESTES/DATA_REGULAR/dnn/mnist/random_iid_mnist_dnn_40%.csv',
    'TESTES/DATA_REGULAR/dnn/mnist/random_iid_mnist_dnn_60%.csv',
    'TESTES/DATA_REGULAR/dnn/mnist/random_iid_mnist_dnn_80%.csv',
]

estilo_linha = ['--', '--', '--', '--', '-', '-', '-', '-']
cor_linha = ['blue', 'red', 'green', 'purple', 'blue', 'red', 'green', 'purple']

rotulos = ['20%', '40%', '60%', '80%', '20%', '40%', '60%', '80%']

# Criar subplots para Accuracy e Loss
# fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(18, 6))

# for i, metrica in enumerate(['accuracy']):
#     # Cria um único gráfico para Accuracy ou Loss com várias linhas
#     for j, arquivo in enumerate(arquivos):
#         data = pd.read_csv(arquivo, header=None)
#         data.columns = ['server_round', 'cid', 'accuracy', 'loss']
#         media_round = data.groupby('server_round').agg({
#             metrica: calcular_media,
#         }).reset_index()

#         axes[i].plot(media_round['server_round'], media_round[metrica], label=f'{rotulos[j]}', linestyle=estilo_linha[j], color=cor_linha[j], linewidth=3)

#     xticks = np.arange(1, 11)
#     axes[i].set_xticks(xticks)
#     axes[i].tick_params(axis='both', which='major', labelsize=tamanho_fonte)
#     axes[i].grid(color='k', linestyle='--', linewidth=0.5, axis='both', alpha=0.1)
#     if metrica == 'loss' :
#         axes[i].legend(
#             loc='best',
#             fontsize=tamanho_fonte,
#             ncol=1,
#             title='% Ataque',
#             title_fontsize=tamanho_fonte
#         )

# # Salva a figura
# plt.tight_layout()
# plt.show()

# plt.figure(figsize=(9, 5))
for i, arquivo_atual in enumerate(arquivos):
    data = pd.read_csv(arquivo_atual, header=None)
    data.columns = ['server_round', 'cid', 'accuracy', 'loss']
    media_round = data.groupby('server_round').agg({
        'accuracy': calcular_media,
    }).reset_index()
    
    
    plt.plot(media_round['server_round'], media_round['accuracy'], label=f'{rotulos[i]}', linewidth=line_width, linestyle=estilo_linha[i], color=cor_linha[i])
    
xticks = np.arange(0,11,1)
plt.xticks(xticks, fontsize=tamanho_fonte)
plt.xticks(fontsize=tamanho_fonte)
plt.yticks(fontsize=tamanho_fonte)
plt.ylabel(y_label_acuracia, fontsize=tamanho_fonte)
plt.xlabel(x_label, fontsize=tamanho_fonte)
# plt.xlabel('# Round', fontsize=tamanho_fonte, labelpad=20)
# plt.ylabel('Loss', fontsize=tamanho_fonte, labelpad=10)

# adiciona grid ao fundo do plot
plt.grid(color='k', linestyle='--', linewidth=2, axis='both', alpha=0.1)

fig = plt.gcf()
fig.set_size_inches(x_fig, y_fig)

plt.savefig('acuracia_figura_3' + formato, dpi=200, bbox_inches = 'tight', pad_inches = 0.05)
plt.show()


# PERDA

for i, arquivo_atual in enumerate(arquivos):
    data = pd.read_csv(arquivo_atual, header=None)
    data.columns = ['server_round', 'cid', 'accuracy', 'loss']
    media_round = data.groupby('server_round').agg({
        'loss': calcular_media,
    }).reset_index()

    plt.plot(media_round['server_round'], media_round['loss'], label=f'{rotulos[i]}', linewidth=line_width, linestyle=estilo_linha[i], color=cor_linha[i])
    
xticks = np.arange(0,11,1)
yticks = np.arange(0,135,20)
plt.xticks(xticks, fontsize=tamanho_fonte)
plt.yticks(yticks, fontsize=tamanho_fonte)
plt.ylabel(y_label_loss, fontsize=tamanho_fonte)
plt.xlabel(x_label, fontsize=tamanho_fonte)
# plt.xlabel('# Round', fontsize=tamanho_fonte, labelpad=20)
# plt.ylabel('Loss', fontsize=tamanho_fonte, labelpad=10)

plt.ylim(0, 130)

legenda = ['20', '40', '60', '80']

plt.legend(
    legenda,
    loc='best',
    fontsize=tamanho_fonte-3,
    ncol=4,
    title=r'% ataque',
    title_fontsize=tamanho_fonte,
    edgecolor       = 'k',
    fancybox        = False,
    frameon         = True,
    handletextpad   = 0.2,
    handlelength    = 2.2,
    handleheight    = 1.2,
    columnspacing   = 0.8,
)

# adiciona grid ao fundo do plot
plt.grid(color='k', linestyle='--', linewidth=2, axis='both', alpha=0.1)

fig = plt.gcf()
fig.set_size_inches(x_fig, y_fig)

plt.savefig('perda_figura_3' + formato, dpi=200, bbox_inches = 'tight', pad_inches = 0.05)
plt.show()

# %% [markdown]
# Este código abaixo gera os gráficos da FIG 2

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np
import os
import glob

# Função para calcular média de uma lista
def calcular_media(lista):
    return sum(lista) / len(lista)

# Ler os dados do arquivo CSV
arquivos =  [   
                'TESTES/diferentes_alphas/normal_Fraction_Fit_iid_mnist_dnn_0.0.csv',
                'TESTES/diferentes_alphas/random_Fraction_Fit_iid_mnist_dnn_0.4.csv',
                'TESTES/diferentes_alphas/random_Fraction_Fit_iid_mnist_dnn_0.6.csv',
                'TESTES/diferentes_alphas/random_Fraction_Fit_iid_mnist_dnn_0.8.csv',
                'TESTES/diferentes_alphas/random_Fraction_Fit_iid_mnist_dnn_1.0.csv',
            ]

rotulos = []

# Criar subplots para Accuracy e Loss
# fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))
        
rotulos= ['0.0','0.1','0.4','0.6','0.8','1.0' ]

# plt.figure(figsize=(9, 5))
for i, arquivo_atual in enumerate(arquivos):
    data = pd.read_csv(arquivo_atual, header=None)
    data.columns = ['server_round', 'cid', 'accuracy', 'loss']
    media_round = data.groupby('server_round').agg({
        'accuracy': calcular_media,
    }).reset_index()
    
    
    plt.plot(media_round['server_round'], media_round['accuracy'], label=f'{rotulos[i]}', linewidth=line_width)
    
xticks = np.arange(0,51,10)
plt.xticks(xticks, fontsize=tamanho_fonte)
plt.xticks(fontsize=tamanho_fonte)
plt.yticks(fontsize=tamanho_fonte)
plt.ylabel(y_label_acuracia, fontsize=tamanho_fonte)
plt.xlabel(x_label, fontsize=tamanho_fonte)
# plt.xlabel('# Round', fontsize=tamanho_fonte, labelpad=20)
# plt.ylabel('Loss', fontsize=tamanho_fonte, labelpad=10)

# adiciona grid ao fundo do plot
plt.grid(color='k', linestyle='--', linewidth=2, axis='both', alpha=0.1)

fig = plt.gcf()
fig.set_size_inches(x_fig, y_fig)

plt.savefig('acuracia_figura_1' + formato, dpi=200, bbox_inches = 'tight', pad_inches = 0.05)
plt.show()





# PERDA


for i, arquivo in enumerate(arquivos):
    data = pd.read_csv(arquivo, header=None)
    data.columns = ['server_round', 'cid', 'accuracy', 'loss']
    media_round = data.groupby('server_round').agg({
        'loss': calcular_media,
    }).reset_index()
    
    plt.plot(media_round['server_round'], media_round['loss'], label=f'{rotulos[i]}', linewidth=line_width)

xticks = np.arange(0,51,10)
plt.xticks(xticks, fontsize=tamanho_fonte)
plt.xticks(fontsize=tamanho_fonte)
plt.yticks(fontsize=tamanho_fonte)
plt.ylabel(y_label_loss, fontsize=tamanho_fonte)
plt.xlabel(x_label, fontsize=tamanho_fonte)
# plt.xlabel('# Round', fontsize=tamanho_fonte, labelpad=20)
# plt.ylabel('Loss', fontsize=tamanho_fonte, labelpad=10)

plt.legend(
    loc='best',
    fontsize=tamanho_fonte,
    ncol=1,
    title=r'$\alpha$',
    title_fontsize=tamanho_fonte,
    edgecolor       = 'k',
    fancybox        = False,
    frameon         = True,
)

# adiciona grid ao fundo do plot
plt.grid(color='k', linestyle='--', linewidth=2, axis='both', alpha=0.1)

fig = plt.gcf()
fig.set_size_inches(x_fig, y_fig)

plt.savefig('perda_figura_1' + formato, dpi=200, bbox_inches = 'tight', pad_inches = 0.05)
plt.show()

# %% [markdown]
# Gera Gráfico 5

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np
import os
import glob

# Função para calcular média de uma lista
def calcular_media(lista):
    return sum(lista) / len(lista)

# Ler os dados do arquivo CSV
arquivos =  [   
                'TESTES/NIID/LOG_EVALUATE/atak_ZEROS_MNIST_DNN_40_0.5_0.0_2.csv',
                'TESTES/NIID/LOG_EVALUATE/atak_ZEROS_MNIST_DNN_40_0.5_0.0_4.csv',
                'TESTES/NIID/LOG_EVALUATE/atak_ZEROS_MNIST_DNN_40_0.5_0.0_6.csv',
                'TESTES/NIID/LOG_EVALUATE/atak_ZEROS_MNIST_DNN_40_0.5_0.0_8.csv',
                'TESTES/NIID/LOG_EVALUATE/atak_ZEROS_MNIST_DNN_40_0.5_0.0_10.csv',
            ]

rotulos = []

# Criar subplots para Accuracy e Loss
# fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))
        
rotulos= ['2','4','6','8','10' ]

# plt.figure(figsize=(9, 5))
for i, arquivo_atual in enumerate(arquivos):
    data = pd.read_csv(arquivo_atual, header=None)
    data.columns = ['server_round', 'cid', 'accuracy', 'loss']
    media_round = data.groupby('server_round').agg({
        'accuracy': calcular_media,
    }).reset_index()
    
    
    plt.plot(media_round['server_round'], media_round['accuracy'], label=f'{rotulos[i]}', linewidth=line_width)
    
xticks = np.arange(0,21,2)
plt.xticks(xticks, fontsize=tamanho_fonte)
plt.xticks(fontsize=tamanho_fonte)
plt.yticks(fontsize=tamanho_fonte)
plt.ylabel(y_label_acuracia, fontsize=tamanho_fonte)
plt.xlabel(x_label, fontsize=tamanho_fonte)
# plt.xlabel('# Round', fontsize=tamanho_fonte, labelpad=20)
# plt.ylabel('Loss', fontsize=tamanho_fonte, labelpad=10)

# adiciona grid ao fundo do plot
plt.grid(color='k', linestyle='--', linewidth=2, axis='both', alpha=0.1)

fig = plt.gcf()
fig.set_size_inches(x_fig, y_fig)

plt.savefig('acuracia_figura_1' + formato, dpi=200, bbox_inches = 'tight', pad_inches = 0.05)
plt.show()





# PERDA


for i, arquivo in enumerate(arquivos):
    data = pd.read_csv(arquivo, header=None)
    data.columns = ['server_round', 'cid', 'accuracy', 'loss']
    media_round = data.groupby('server_round').agg({
        'loss': calcular_media,
    }).reset_index()
    
    plt.plot(media_round['server_round'], media_round['loss'], label=f'{rotulos[i]}', linewidth=line_width)

xticks = np.arange(0,21,2)
plt.xticks(xticks, fontsize=tamanho_fonte)
plt.xticks(fontsize=tamanho_fonte)
plt.yticks(fontsize=tamanho_fonte)
plt.ylabel(y_label_loss, fontsize=tamanho_fonte)
plt.xlabel(x_label, fontsize=tamanho_fonte)
# plt.xlabel('# Round', fontsize=tamanho_fonte, labelpad=20)
# plt.ylabel('Loss', fontsize=tamanho_fonte, labelpad=10)

plt.legend(
    loc='best',
    fontsize=tamanho_fonte,
    ncol=1,
    title='Rodadas de início',
    title_fontsize=tamanho_fonte,
    edgecolor       = 'k',
    fancybox        = False,
    frameon         = True,
)

# adiciona grid ao fundo do plot
plt.grid(color='k', linestyle='--', linewidth=2, axis='both', alpha=0.1)

fig = plt.gcf()
fig.set_size_inches(x_fig, y_fig)

plt.savefig('perda_figura_1' + formato, dpi=200, bbox_inches = 'tight', pad_inches = 0.05)
plt.show()

# %% [markdown]
# Ainda relacionado a FIG 5

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np
import os
import glob

# Função para calcular média de uma lista
def calcular_media(lista):
    return sum(lista) / len(lista)

# Ler os dados do arquivo CSV
arquivos =  [   
                'TESTES/NIID/LOG_EVALUATE/ZEROS_MNIST_DNN_40_0.5_0.0_2.csv',
                'TESTES/NIID/LOG_EVALUATE/ZEROS_MNIST_DNN_40_0.5_0.0_4.csv',
                'TESTES/NIID/LOG_EVALUATE/ZEROS_MNIST_DNN_40_0.5_0.0_6.csv',
                'TESTES/NIID/LOG_EVALUATE/ZEROS_MNIST_DNN_40_0.5_0.0_8.csv',
                'TESTES/NIID/LOG_EVALUATE/ZEROS_MNIST_DNN_40_0.5_0.0_10.csv',
            ]

rotulos = []

# Criar subplots para Accuracy e Loss
# fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))
        
rotulos= ['2','4','6','8','10' ]

# plt.figure(figsize=(9, 5))
for i, arquivo_atual in enumerate(arquivos):
    data = pd.read_csv(arquivo_atual, header=None)
    data.columns = ['server_round', 'cid', 'accuracy', 'loss']
    media_round = data.groupby('server_round').agg({
        'accuracy': calcular_media,
    }).reset_index()
    
    
    plt.plot(media_round['server_round'], media_round['accuracy'], label=f'{rotulos[i]}', linewidth=line_width)
    
xticks = np.arange(0,21,2)
plt.xticks(xticks, fontsize=tamanho_fonte)
plt.xticks(fontsize=tamanho_fonte)
plt.yticks(fontsize=tamanho_fonte)
plt.ylabel(y_label_acuracia, fontsize=tamanho_fonte)
plt.xlabel(x_label, fontsize=tamanho_fonte)
# plt.xlabel('# Round', fontsize=tamanho_fonte, labelpad=20)
# plt.ylabel('Loss', fontsize=tamanho_fonte, labelpad=10)

# adiciona grid ao fundo do plot
plt.grid(color='k', linestyle='--', linewidth=2, axis='both', alpha=0.1)

fig = plt.gcf()
fig.set_size_inches(x_fig, y_fig)

plt.savefig('acuracia_figura_1' + formato, dpi=200, bbox_inches = 'tight', pad_inches = 0.05)
plt.show()





# PERDA


for i, arquivo in enumerate(arquivos):
    data = pd.read_csv(arquivo, header=None)
    data.columns = ['server_round', 'cid', 'accuracy', 'loss']
    media_round = data.groupby('server_round').agg({
        'loss': calcular_media,
    }).reset_index()
    
    plt.plot(media_round['server_round'], media_round['loss'], label=f'{rotulos[i]}', linewidth=line_width)

xticks = np.arange(0,21,2)
plt.xticks(xticks, fontsize=tamanho_fonte)
plt.xticks(fontsize=tamanho_fonte)
plt.yticks(fontsize=tamanho_fonte)
plt.ylabel(y_label_loss, fontsize=tamanho_fonte)
plt.xlabel(x_label, fontsize=tamanho_fonte)
# plt.xlabel('# Round', fontsize=tamanho_fonte, labelpad=20)
# plt.ylabel('Loss', fontsize=tamanho_fonte, labelpad=10)

plt.legend(
    loc='best',
    fontsize=tamanho_fonte,
    ncol=1,
    title='Rodadas de início',
    title_fontsize=tamanho_fonte,
    edgecolor       = 'k',
    fancybox        = False,
    frameon         = True,
)

# adiciona grid ao fundo do plot
plt.grid(color='k', linestyle='--', linewidth=2, axis='both', alpha=0.1)

fig = plt.gcf()
fig.set_size_inches(x_fig, y_fig)

plt.savefig('perda_figura_1' + formato, dpi=200, bbox_inches = 'tight', pad_inches = 0.05)
plt.show()

# %% [markdown]
# FIG 6

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np
import os
import glob

# Função para calcular média de uma lista
def calcular_media(lista):
    return sum(lista) / len(lista)

# Ler os dados do arquivo CSV
arquivos =  [   
                'TESTES/IID/LOG_EVALUATE/atak_INVERTE_CONVEGENCIA_MNIST_DNN_40_0.0_0.0_2.csv',
                'TESTES/IID/LOG_EVALUATE/atak_INVERTE_CONVEGENCIA_MNIST_DNN_40_0.0_0.0_4.csv',
                'TESTES/IID/LOG_EVALUATE/atak_INVERTE_CONVEGENCIA_MNIST_DNN_40_0.0_0.0_6.csv',
                'TESTES/IID/LOG_EVALUATE/atak_INVERTE_CONVEGENCIA_MNIST_DNN_40_0.0_0.0_8.csv',
                'TESTES/IID/LOG_EVALUATE/atak_INVERTE_CONVEGENCIA_MNIST_DNN_40_0.0_0.0_10.csv',
            ]

rotulos = []

# Criar subplots para Accuracy e Loss
# fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))
        
rotulos= ['2','4','6','8','10' ]

# plt.figure(figsize=(9, 5))
for i, arquivo_atual in enumerate(arquivos):
    data = pd.read_csv(arquivo_atual, header=None)
    data.columns = ['server_round', 'cid', 'accuracy', 'loss']
    media_round = data.groupby('server_round').agg({
        'accuracy': calcular_media,
    }).reset_index()
    
    
    plt.plot(media_round['server_round'], media_round['accuracy'], label=f'{rotulos[i]}', linewidth=line_width)
    
xticks = np.arange(0,21,2)
plt.xticks(xticks, fontsize=tamanho_fonte)
plt.xticks(fontsize=tamanho_fonte)
plt.yticks(fontsize=tamanho_fonte)
plt.ylabel(y_label_acuracia, fontsize=tamanho_fonte)
plt.xlabel(x_label, fontsize=tamanho_fonte)
# plt.xlabel('# Round', fontsize=tamanho_fonte, labelpad=20)
# plt.ylabel('Loss', fontsize=tamanho_fonte, labelpad=10)

# adiciona grid ao fundo do plot
plt.grid(color='k', linestyle='--', linewidth=2, axis='both', alpha=0.1)

fig = plt.gcf()
fig.set_size_inches(x_fig, y_fig)

plt.savefig('acuracia_figura_1' + formato, dpi=200, bbox_inches = 'tight', pad_inches = 0.05)
plt.show()





# PERDA


for i, arquivo in enumerate(arquivos):
    data = pd.read_csv(arquivo, header=None)
    data.columns = ['server_round', 'cid', 'accuracy', 'loss']
    media_round = data.groupby('server_round').agg({
        'loss': calcular_media,
    }).reset_index()
    
    plt.plot(media_round['server_round'], media_round['loss'], label=f'{rotulos[i]}', linewidth=line_width)

xticks = np.arange(0,21,2)
plt.xticks(xticks, fontsize=tamanho_fonte)
plt.xticks(fontsize=tamanho_fonte)
plt.yticks(fontsize=tamanho_fonte)
plt.ylabel(y_label_loss, fontsize=tamanho_fonte)
plt.xlabel(x_label, fontsize=tamanho_fonte)
# plt.xlabel('# Round', fontsize=tamanho_fonte, labelpad=20)
# plt.ylabel('Loss', fontsize=tamanho_fonte, labelpad=10)

plt.legend(
    loc='best',
    fontsize=tamanho_fonte,
    ncol=1,
    title='Rodadas de início',
    title_fontsize=tamanho_fonte,
    edgecolor       = 'k',
    fancybox        = False,
    frameon         = True,
)

# adiciona grid ao fundo do plot
plt.grid(color='k', linestyle='--', linewidth=2, axis='both', alpha=0.1)

fig = plt.gcf()
fig.set_size_inches(x_fig, y_fig)

plt.savefig('perda_figura_1' + formato, dpi=200, bbox_inches = 'tight', pad_inches = 0.05)
plt.show()

# %% [markdown]
# Ainda referente a FIG 6

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np
import os
import glob

# Função para calcular média de uma lista
def calcular_media(lista):
    return sum(lista) / len(lista)

# Ler os dados do arquivo CSV
arquivos =  [   
                'TESTES/IID/LOG_EVALUATE/INVERTE_CONVEGENCIA_MNIST_DNN_40_0.0_0.0_2.csv',
                'TESTES/IID/LOG_EVALUATE/INVERTE_CONVEGENCIA_MNIST_DNN_40_0.0_0.0_4.csv',
                'TESTES/IID/LOG_EVALUATE/INVERTE_CONVEGENCIA_MNIST_DNN_40_0.0_0.0_6.csv',
                'TESTES/IID/LOG_EVALUATE/INVERTE_CONVEGENCIA_MNIST_DNN_40_0.0_0.0_8.csv',
                'TESTES/IID/LOG_EVALUATE/INVERTE_CONVEGENCIA_MNIST_DNN_40_0.0_0.0_10.csv',
            ]

rotulos = []

# Criar subplots para Accuracy e Loss
# fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))
        
rotulos= ['2','4','6','8','10' ]

# plt.figure(figsize=(9, 5))
for i, arquivo_atual in enumerate(arquivos):
    data = pd.read_csv(arquivo_atual, header=None)
    data.columns = ['server_round', 'cid', 'accuracy', 'loss']
    media_round = data.groupby('server_round').agg({
        'accuracy': calcular_media,
    }).reset_index()
    
    
    plt.plot(media_round['server_round'], media_round['accuracy'], label=f'{rotulos[i]}', linewidth=line_width)
    
xticks = np.arange(0,21,2)
plt.xticks(xticks, fontsize=tamanho_fonte)
plt.xticks(fontsize=tamanho_fonte)
plt.yticks(fontsize=tamanho_fonte)
plt.ylabel(y_label_acuracia, fontsize=tamanho_fonte)
plt.xlabel(x_label, fontsize=tamanho_fonte)
# plt.xlabel('# Round', fontsize=tamanho_fonte, labelpad=20)
# plt.ylabel('Loss', fontsize=tamanho_fonte, labelpad=10)

# adiciona grid ao fundo do plot
plt.grid(color='k', linestyle='--', linewidth=2, axis='both', alpha=0.1)

fig = plt.gcf()
fig.set_size_inches(x_fig, y_fig)

plt.savefig('acuracia_figura_1' + formato, dpi=200, bbox_inches = 'tight', pad_inches = 0.05)
plt.show()





# PERDA


for i, arquivo in enumerate(arquivos):
    data = pd.read_csv(arquivo, header=None)
    data.columns = ['server_round', 'cid', 'accuracy', 'loss']
    media_round = data.groupby('server_round').agg({
        'loss': calcular_media,
    }).reset_index()
    
    plt.plot(media_round['server_round'], media_round['loss'], label=f'{rotulos[i]}', linewidth=line_width)

xticks = np.arange(0,21,2)
plt.xticks(xticks, fontsize=tamanho_fonte)
plt.xticks(fontsize=tamanho_fonte)
plt.yticks(fontsize=tamanho_fonte)
plt.ylabel(y_label_loss, fontsize=tamanho_fonte)
plt.xlabel(x_label, fontsize=tamanho_fonte)
# plt.xlabel('# Round', fontsize=tamanho_fonte, labelpad=20)
# plt.ylabel('Loss', fontsize=tamanho_fonte, labelpad=10)

plt.legend(
    loc='best',
    fontsize=tamanho_fonte,
    ncol=1,
    title='Rodadas de início',
    title_fontsize=tamanho_fonte,
    edgecolor       = 'k',
    fancybox        = False,
    frameon         = True,
)

# adiciona grid ao fundo do plot
plt.grid(color='k', linestyle='--', linewidth=2, axis='both', alpha=0.1)

fig = plt.gcf()
fig.set_size_inches(x_fig, y_fig)

plt.savefig('perda_figura_1' + formato, dpi=200, bbox_inches = 'tight', pad_inches = 0.05)
plt.show()

# %% [markdown]
# Ainda FIG 6

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np
import os
import glob

# Função para calcular média de uma lista
def calcular_media(lista):
    return sum(lista) / len(lista)

# Ler os dados do arquivo CSV
arquivos =  [   
                'TESTES/IID/LOG_EVALUATE/INVERTE_CONVEGENCIA_CIFAR10_CNN_40_0.0_0.0_2.csv',
                'TESTES/IID/LOG_EVALUATE/INVERTE_CONVEGENCIA_CIFAR10_CNN_40_0.0_0.0_4.csv',
                'TESTES/IID/LOG_EVALUATE/INVERTE_CONVEGENCIA_CIFAR10_CNN_40_0.0_0.0_6.csv',
                'TESTES/IID/LOG_EVALUATE/INVERTE_CONVEGENCIA_CIFAR10_CNN_40_0.0_0.0_8.csv',
                'TESTES/IID/LOG_EVALUATE/INVERTE_CONVEGENCIA_CIFAR10_CNN_40_0.0_0.0_10.csv',
            ]

rotulos = []

# Criar subplots para Accuracy e Loss
# fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))
        
rotulos= ['2','4','6','8','10' ]

# plt.figure(figsize=(9, 5))
for i, arquivo_atual in enumerate(arquivos):
    data = pd.read_csv(arquivo_atual, header=None)
    data.columns = ['server_round', 'cid', 'accuracy', 'loss']
    media_round = data.groupby('server_round').agg({
        'accuracy': calcular_media,
    }).reset_index()
    
    
    plt.plot(media_round['server_round'], media_round['accuracy'], label=f'{rotulos[i]}', linewidth=line_width)
    
xticks = np.arange(0,21,2)
plt.xticks(xticks, fontsize=tamanho_fonte)
plt.xticks(fontsize=tamanho_fonte)
plt.yticks(fontsize=tamanho_fonte)
plt.ylabel(y_label_acuracia, fontsize=tamanho_fonte)
plt.xlabel(x_label, fontsize=tamanho_fonte)
# plt.xlabel('# Round', fontsize=tamanho_fonte, labelpad=20)
# plt.ylabel('Loss', fontsize=tamanho_fonte, labelpad=10)

# adiciona grid ao fundo do plot
plt.grid(color='k', linestyle='--', linewidth=2, axis='both', alpha=0.1)

fig = plt.gcf()
fig.set_size_inches(x_fig, y_fig)

plt.savefig('acuracia_figura_1' + formato, dpi=200, bbox_inches = 'tight', pad_inches = 0.05)
plt.show()





# PERDA


for i, arquivo in enumerate(arquivos):
    data = pd.read_csv(arquivo, header=None)
    data.columns = ['server_round', 'cid', 'accuracy', 'loss']
    media_round = data.groupby('server_round').agg({
        'loss': calcular_media,
    }).reset_index()
    
    plt.plot(media_round['server_round'], media_round['loss'], label=f'{rotulos[i]}', linewidth=line_width)

xticks = np.arange(0,21,2)
plt.xticks(xticks, fontsize=tamanho_fonte)
plt.xticks(fontsize=tamanho_fonte)
plt.yticks(fontsize=tamanho_fonte)
plt.ylabel(y_label_loss, fontsize=tamanho_fonte)
plt.xlabel(x_label, fontsize=tamanho_fonte)
# plt.xlabel('# Round', fontsize=tamanho_fonte, labelpad=20)
# plt.ylabel('Loss', fontsize=tamanho_fonte, labelpad=10)

plt.legend(
    loc='best',
    fontsize=tamanho_fonte,
    ncol=1,
    title='Rodadas de início',
    title_fontsize=tamanho_fonte,
    edgecolor       = 'k',
    fancybox        = False,
    frameon         = True,
)

# adiciona grid ao fundo do plot
plt.grid(color='k', linestyle='--', linewidth=2, axis='both', alpha=0.1)

fig = plt.gcf()
fig.set_size_inches(x_fig, y_fig)

plt.savefig('perda_figura_1' + formato, dpi=200, bbox_inches = 'tight', pad_inches = 0.05)
plt.show()

# %% [markdown]
# FIG 7

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np
import os
import glob

# Função para calcular média de uma lista
def calcular_media(lista):
    return sum(lista) / len(lista)

# Ler os dados do arquivo CSV
arquivos =  [   
                'TESTES/IID/LOG_EVALUATE/atak_INVERTE_TREINANDO_MNIST_DNN_40_0.0_0.0_2.csv',
                'TESTES/IID/LOG_EVALUATE/atak_INVERTE_TREINANDO_MNIST_DNN_40_0.0_0.0_4.csv',
                'TESTES/IID/LOG_EVALUATE/atak_INVERTE_TREINANDO_MNIST_DNN_40_0.0_0.0_6.csv',
                'TESTES/IID/LOG_EVALUATE/atak_INVERTE_TREINANDO_MNIST_DNN_40_0.0_0.0_8.csv',
                'TESTES/IID/LOG_EVALUATE/atak_INVERTE_TREINANDO_MNIST_DNN_40_0.0_0.0_10.csv',
            ]

rotulos = []

# Criar subplots para Accuracy e Loss
# fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))
        
rotulos= ['2','4','6','8','10' ]

# plt.figure(figsize=(9, 5))
for i, arquivo_atual in enumerate(arquivos):
    data = pd.read_csv(arquivo_atual, header=None)
    data.columns = ['server_round', 'cid', 'accuracy', 'loss']
    media_round = data.groupby('server_round').agg({
        'accuracy': calcular_media,
    }).reset_index()
    
    
    plt.plot(media_round['server_round'], media_round['accuracy'], label=f'{rotulos[i]}', linewidth=line_width)
    
xticks = np.arange(0,21,2)
plt.xticks(xticks, fontsize=tamanho_fonte)
plt.xticks(fontsize=tamanho_fonte)
plt.yticks(fontsize=tamanho_fonte)
plt.ylabel(y_label_acuracia, fontsize=tamanho_fonte)
plt.xlabel(x_label, fontsize=tamanho_fonte)
# plt.xlabel('# Round', fontsize=tamanho_fonte, labelpad=20)
# plt.ylabel('Loss', fontsize=tamanho_fonte, labelpad=10)

# adiciona grid ao fundo do plot
plt.grid(color='k', linestyle='--', linewidth=2, axis='both', alpha=0.1)

fig = plt.gcf()
fig.set_size_inches(x_fig, y_fig)

plt.savefig('acuracia_figura_1' + formato, dpi=200, bbox_inches = 'tight', pad_inches = 0.05)
plt.show()





# PERDA


for i, arquivo in enumerate(arquivos):
    data = pd.read_csv(arquivo, header=None)
    data.columns = ['server_round', 'cid', 'accuracy', 'loss']
    media_round = data.groupby('server_round').agg({
        'loss': calcular_media,
    }).reset_index()
    
    plt.plot(media_round['server_round'], media_round['loss'], label=f'{rotulos[i]}', linewidth=line_width)

xticks = np.arange(0,21,2)
plt.xticks(xticks, fontsize=tamanho_fonte)
plt.xticks(fontsize=tamanho_fonte)
plt.yticks(fontsize=tamanho_fonte)
plt.ylabel(y_label_loss, fontsize=tamanho_fonte)
plt.xlabel(x_label, fontsize=tamanho_fonte)
# plt.xlabel('# Round', fontsize=tamanho_fonte, labelpad=20)
# plt.ylabel('Loss', fontsize=tamanho_fonte, labelpad=10)

plt.legend(
    loc='best',
    fontsize=tamanho_fonte,
    ncol=1,
    title='Rodadas de início',
    title_fontsize=tamanho_fonte,
    edgecolor       = 'k',
    fancybox        = False,
    frameon         = True,
)

# adiciona grid ao fundo do plot
plt.grid(color='k', linestyle='--', linewidth=2, axis='both', alpha=0.1)

fig = plt.gcf()
fig.set_size_inches(x_fig, y_fig)

plt.savefig('perda_figura_1' + formato, dpi=200, bbox_inches = 'tight', pad_inches = 0.05)
plt.show()

# %% [markdown]
# Ainda FIG 7

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np
import os
import glob

# Função para calcular média de uma lista
def calcular_media(lista):
    return sum(lista) / len(lista)

# Ler os dados do arquivo CSV
arquivos =  [   
                'TESTES/IID/LOG_EVALUATE/INVERTE_TREINANDO_MNIST_DNN_40_0.0_0.0_2.csv',
                'TESTES/IID/LOG_EVALUATE/INVERTE_TREINANDO_MNIST_DNN_40_0.0_0.0_4.csv',
                'TESTES/IID/LOG_EVALUATE/INVERTE_TREINANDO_MNIST_DNN_40_0.0_0.0_6.csv',
                'TESTES/IID/LOG_EVALUATE/INVERTE_TREINANDO_MNIST_DNN_40_0.0_0.0_8.csv',
                'TESTES/IID/LOG_EVALUATE/INVERTE_TREINANDO_MNIST_DNN_40_0.0_0.0_10.csv',
            ]

rotulos = []

# Criar subplots para Accuracy e Loss
# fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))
        
rotulos= ['2','4','6','8','10' ]

# plt.figure(figsize=(9, 5))
for i, arquivo_atual in enumerate(arquivos):
    data = pd.read_csv(arquivo_atual, header=None)
    data.columns = ['server_round', 'cid', 'accuracy', 'loss']
    media_round = data.groupby('server_round').agg({
        'accuracy': calcular_media,
    }).reset_index()
    
    
    plt.plot(media_round['server_round'], media_round['accuracy'], label=f'{rotulos[i]}', linewidth=line_width)
    
xticks = np.arange(0,21,2)
plt.xticks(xticks, fontsize=tamanho_fonte)
plt.xticks(fontsize=tamanho_fonte)
plt.yticks(fontsize=tamanho_fonte)
plt.ylabel(y_label_acuracia, fontsize=tamanho_fonte)
plt.xlabel(x_label, fontsize=tamanho_fonte)
# plt.xlabel('# Round', fontsize=tamanho_fonte, labelpad=20)
# plt.ylabel('Loss', fontsize=tamanho_fonte, labelpad=10)

# adiciona grid ao fundo do plot
plt.grid(color='k', linestyle='--', linewidth=2, axis='both', alpha=0.1)

fig = plt.gcf()
fig.set_size_inches(x_fig, y_fig)

plt.savefig('acuracia_figura_1' + formato, dpi=200, bbox_inches = 'tight', pad_inches = 0.05)
plt.show()





# PERDA


for i, arquivo in enumerate(arquivos):
    data = pd.read_csv(arquivo, header=None)
    data.columns = ['server_round', 'cid', 'accuracy', 'loss']
    media_round = data.groupby('server_round').agg({
        'loss': calcular_media,
    }).reset_index()
    
    plt.plot(media_round['server_round'], media_round['loss'], label=f'{rotulos[i]}', linewidth=line_width)

xticks = np.arange(0,21,2)
plt.xticks(xticks, fontsize=tamanho_fonte)
plt.xticks(fontsize=tamanho_fonte)
plt.yticks(fontsize=tamanho_fonte)
plt.ylabel(y_label_loss, fontsize=tamanho_fonte)
plt.xlabel(x_label, fontsize=tamanho_fonte)
# plt.xlabel('# Round', fontsize=tamanho_fonte, labelpad=20)
# plt.ylabel('Loss', fontsize=tamanho_fonte, labelpad=10)

plt.legend(
    loc='best',
    fontsize=tamanho_fonte,
    ncol=1,
    title='Rodadas de início',
    title_fontsize=tamanho_fonte,
    edgecolor       = 'k',
    fancybox        = False,
    frameon         = True,
)

# adiciona grid ao fundo do plot
plt.grid(color='k', linestyle='--', linewidth=2, axis='both', alpha=0.1)

fig = plt.gcf()
fig.set_size_inches(x_fig, y_fig)

plt.savefig('perda_figura_1' + formato, dpi=200, bbox_inches = 'tight', pad_inches = 0.05)
plt.show()

# %% [markdown]
# FIG 8

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np
import os
import glob

# Função para calcular média de uma lista
def calcular_media(lista):
    return sum(lista) / len(lista)

# Ler os dados do arquivo CSV
arquivos =  [   
                'TESTES/IID/LOG_EVALUATE/atak_INVERTE_TREINANDO_MNIST_DNN_40_0.0_0.0_2.csv',
                'TESTES/IID/LOG_EVALUATE/atak_INVERTE_TREINANDO_MNIST_DNN_40_0.0_0.0_4.csv',
                'TESTES/IID/LOG_EVALUATE/atak_INVERTE_TREINANDO_MNIST_DNN_40_0.0_0.0_6.csv',
                'TESTES/IID/LOG_EVALUATE/atak_INVERTE_TREINANDO_MNIST_DNN_40_0.0_0.0_8.csv',
                'TESTES/IID/LOG_EVALUATE/atak_INVERTE_TREINANDO_MNIST_DNN_40_0.0_0.0_10.csv',
            ]

rotulos = []

# Criar subplots para Accuracy e Loss
# fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))
        
rotulos= ['2','4','6','8','10' ]

# plt.figure(figsize=(9, 5))
for i, arquivo_atual in enumerate(arquivos):
    data = pd.read_csv(arquivo_atual, header=None)
    data.columns = ['server_round', 'cid', 'accuracy', 'loss']
    media_round = data.groupby('server_round').agg({
        'accuracy': calcular_media,
    }).reset_index()
    
    
    plt.plot(media_round['server_round'], media_round['accuracy'], label=f'{rotulos[i]}', linewidth=line_width)
    
xticks = np.arange(0,21,2)
plt.xticks(xticks, fontsize=tamanho_fonte)
plt.xticks(fontsize=tamanho_fonte)
plt.yticks(fontsize=tamanho_fonte)
plt.ylabel(y_label_acuracia, fontsize=tamanho_fonte)
plt.xlabel(x_label, fontsize=tamanho_fonte)
# plt.xlabel('# Round', fontsize=tamanho_fonte, labelpad=20)
# plt.ylabel('Loss', fontsize=tamanho_fonte, labelpad=10)

# adiciona grid ao fundo do plot
plt.grid(color='k', linestyle='--', linewidth=2, axis='both', alpha=0.1)

fig = plt.gcf()
fig.set_size_inches(x_fig, y_fig)

plt.savefig('acuracia_figura_1' + formato, dpi=200, bbox_inches = 'tight', pad_inches = 0.05)
plt.show()





# PERDA


for i, arquivo in enumerate(arquivos):
    data = pd.read_csv(arquivo, header=None)
    data.columns = ['server_round', 'cid', 'accuracy', 'loss']
    media_round = data.groupby('server_round').agg({
        'loss': calcular_media,
    }).reset_index()
    
    plt.plot(media_round['server_round'], media_round['loss'], label=f'{rotulos[i]}', linewidth=line_width)

xticks = np.arange(0,21,2)
plt.xticks(xticks, fontsize=tamanho_fonte)
plt.xticks(fontsize=tamanho_fonte)
plt.yticks(fontsize=tamanho_fonte)
plt.ylabel(y_label_loss, fontsize=tamanho_fonte)
plt.xlabel(x_label, fontsize=tamanho_fonte)
# plt.xlabel('# Round', fontsize=tamanho_fonte, labelpad=20)
# plt.ylabel('Loss', fontsize=tamanho_fonte, labelpad=10)

plt.legend(
    loc='best',
    fontsize=tamanho_fonte,
    ncol=1,
    title='Rodadas de início',
    title_fontsize=tamanho_fonte,
    edgecolor       = 'k',
    fancybox        = False,
    frameon         = True,
)

# adiciona grid ao fundo do plot
plt.grid(color='k', linestyle='--', linewidth=2, axis='both', alpha=0.1)

fig = plt.gcf()
fig.set_size_inches(x_fig, y_fig)

plt.savefig('perda_figura_1' + formato, dpi=200, bbox_inches = 'tight', pad_inches = 0.05)
plt.show()
